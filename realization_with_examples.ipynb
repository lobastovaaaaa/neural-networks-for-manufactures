# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import keras
from tensorflow.python.keras.models import load_model
from tensorflow.python.keras.preprocessing import image
import numpy as np

def helmet_predict (model, image_file):
  label_names = ['helmet', 'no helmet']
  img = keras.preprocessing.image.load_img(image_file, target_size = (150, 150))
  img_arr = np.expand_dims(img, axis = 0) / 255.0
  result = model.predict_classes(img_arr)
  print('Result: {}'.format(label_names[result[0][0]]))

model = load_model('/content/drive/My Drive/uir/uir4.h5')
helmet_predict(model, '/content/drive/My Drive/image.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-db251ff170d2> in <module>()
#      12
#      13 model = load_model('/content/drive/My Drive/uir/uir4.h5')
# ---> 14 helmet_predict(model, '/content/drive/My Drive/image.jpg')
#
# <ipython-input-3-db251ff170d2> in helmet_predict(model, image_file)
#       6 def helmet_predict (model, image_file):
#       7   label_names = ['helmet', 'no helmet']
# ----> 8   img = keras.preprocessing.image.load_img(image_file, target_size = (150, 150))
#       9   img_arr = np.expand_dims(img, axis = 0) / 255.0
#      10   result = model.predict_classes(img_arr)
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/image/utils.py in load_img(path, grayscale, color_mode, target_size, interpolation)
#     108         raise ImportError('Could not import PIL.Image. '
# ...
